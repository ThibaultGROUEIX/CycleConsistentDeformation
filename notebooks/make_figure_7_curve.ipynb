# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import PyQt5

# %%
x = [1,3,5,9,17,33,65,129,"all"]
x_loc = np.arange(9)

# %%
# Use `training/inference_miou_refacto.py` to populate these values
Airplane_NN_ours   = [78.65,  80.46,  81.44,  81.31,  80.70,  79.57,  77.91,  75.75,  65.99,  ]
Airplane_NN_NN   = [78.78, 80.64, 81.38, 81.41, 80.91, 79.68, 77.59, 74.72, 65.99, ]
Airplane_Chamfer_ours   = [80.28, 81.94, 82.90, 83.03, 82.75, 82.12, 80.54, 77.88, 65.99, ]
Airplane_Chamfer_NN   = [79.24, 81.56, 82.14, 82.06, 81.75, 80.54, 78.60, 75.41, 65.99, ]
Airplane_Cosine_ours   = [78.70, 80.51, 81.71, 82.17, 81.32, 80.58, 78.93, 76.80, 65.99, ]
Airplane_Cosine_NN   = [78.55, 80.24, 81.90, 82.12, 81.27, 80.57, 77.83, 75.18, 65.99, ]
Airplane_Cycle_ours   = [78.06, 80.03, 80.67, 81.33, 81.37, 80.45, 78.58, 77.16, 65.99, ]
Airplane_Cycle_NN   = [74.40, 76.48, 77.53, 77.80, 78.29, 77.61, 75.61, 73.69, 65.99, ]

# %%
# %pylab qt
# %matplotlib inline
plt.axhline(y=83.4, xmin=0, xmax=7, linestyle =':', color='k', label = "Pointnet")
plt.plot(x, Airplane_NN_ours, '.-', label="Nearest Neighbor + Ours", color='c')
plt.plot(x, Airplane_NN_NN, '.:', label="Nearest Neighbor + Identity", color='c')
plt.plot(x, Airplane_Chamfer_ours, '.-', label="Deformation Distance + Ours", color='r')
plt.plot(x, Airplane_Chamfer_NN, '.:', label="Deformation Distance + Identity", color='r')
plt.plot(x, Airplane_Cosine_ours, '.-', label="Cosine Distance + Ours", color='b')
plt.plot(x, Airplane_Cosine_NN, '.:', label="Cosine Distance + Identity", color='b')
plt.plot(x, Airplane_Cycle_ours, '.-', label="Cycle Consistency + Ours", color='y')
plt.plot(x, Airplane_Cycle_NN, '.:', label="Cycle Consistency + Identity", color='y')
plt.xlabel('Number of voting shapes', fontsize=17)
plt.xticks(x_loc, x_label, fontsize=17)
plt.title("Airplane",fontsize=23)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.tight_layout()
plt.scatter(0, 87.9, s=150, color='r', marker='*', label='Oracle + Ours')

plt.yticks(fontsize=17)
plt.ylabel('IoU', fontsize=17)
#legend = plt.legend(loc='lower center', shadow=True, fontsize='x-large')
plt.savefig("Airplane.png")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Car_NN_ours = [71.01,72.42,73.16,74.13,73.80,72.27,69.91,67.11,64.57]
Car_NN_NN = [70.55,72.06,73.03,74.09,73.76,73.14,70.37,67.75,64.06]
Car_Chamfer_ours = [71.59,73.64,74.04,73.85,72.49,71.51,68.64,66.60,64.57]
Car_Chamfer_NN = [70.03,71.77,72.80,72.24,71.99,70.97,68.84,66.91,64.06]
Car_Cosine_ours = [69.69,72.38,73.37,74.13,74.50,73.95,72.29,68.80,64.57]
Car_Cosine_NN = [68.98,72.07,72.76,73.77,74.01,73.29,71.77,68.73,64.06]
Car_Cycle_ours = [68.73,70.16,71.35,72.38,72.28,71.13,69.00,66.41,64.57]
Car_Cycle_NN = [67.09,68.44,69.87,70.78,70.76,70.33,68.85,66.63,64.06]

# %%
# %pylab qt
# %matplotlib inline
plt.axhline(y=74.9, xmin=0, xmax=7, linestyle =':', color='k', label = "Pointnet")
plt.plot(x, Car_NN_ours, '.-', label="Nearest Neighbors + Ours", color='c')
plt.plot(x, Car_NN_NN, '.:', label="Nearest Neighbors + Identity", color='c')
plt.plot(x, Car_Chamfer_ours, '.-', label="Chamfer Distance + Ours", color='r')
plt.plot(x, Car_Chamfer_NN, '.:', label="Chamfer Distance + Identity", color='r')
plt.plot(x, Car_Cosine_ours, '.-', label="Cosine Distance + Ours", color='b')
plt.plot(x, Car_Cosine_NN, '.:', label="Cosine Distance + Identity", color='b')
plt.plot(x, Car_Cycle_ours, '.-', label="Cycle Consistency + Ours", color='y')
plt.plot(x, Car_Cycle_NN, '.:', label="Cycle Consistency + Identity", color='y')
plt.xlabel('Number of voting shapes', fontsize=17)
plt.xticks(x_loc, x_label, fontsize=17)
plt.title("Car",fontsize=23)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.yticks(fontsize=17)
plt.ylabel('IoU', fontsize=17)
plt.tight_layout()
plt.scatter(0, 78.9, s=150, color='r', marker='*',label='Oracle + ours')

#legend = plt.legend(loc='lower center', shadow=True, fontsize='x-large')
plt.savefig("Car.png")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Chair_NN_ours = [85.91,86.51,86.63,86.62,86.51,86.26,85.87,84.97,82.79,]
Chair_NN_NN = [85.36,86.02,86.25,86.19,86.03,85.80,85.22,84.11,76.73,]
Chair_Chamfer_ours = [87.30,88.08,88.38,88.33,88.24,87.62,87.14,86.64,82.79,]
Chair_Chamfer_NN = [82.74,83.81,84.13,84.31,84.03,83.60,83.01,82.10,76.73,]
Chair_Cosine_ours = [86.48,87.29,87.91,87.85,87.59,86.87,86.52,85.72,82.79,]
Chair_Cosine_NN = [85.64,86.43,86.97,87.10,86.70,86.09,85.70,84.54,76.73,]
Chair_Cycle_ours = [87.08,88.08,88.11,88.20,88.26,87.75,87.33,86.57,82.79,]
Chair_Cycle_NN = [81.88,82.92,83.21,83.39,83.36,82.98,82.32,81.48,76.73,]

# %%
# %pylab qt
# %matplotlib inline
plt.scatter(0, 93.0,  s=150, color='r', marker='*', label='Oracle + ours')
plt.axhline(y=89.6, xmin=0, xmax=7, linestyle =':', color='k', label = "Pointnet")
plt.plot(x, Chair_NN_ours, '.-', label="Nearest Neighbors + Ours", color='c')
plt.plot(x, Chair_NN_NN, '.:', label="Nearest Neighbors + Identity", color='c')
plt.plot(x, Chair_Chamfer_ours, '.-', label="Chamfer Distance + Ours", color='r')
plt.plot(x, Chair_Chamfer_NN, '.:', label="Chamfer Distance + Identity", color='r')
plt.plot(x, Chair_Cosine_ours, '.-', label="Cosine Distance + Ours", color='b')
plt.plot(x, Chair_Cosine_NN, '.:', label="Cosine Distance + Identity", color='b')
plt.plot(x, Chair_Cycle_ours, '.-', label="Cycle Consistency + Ours", color='y')
plt.plot(x, Chair_Cycle_NN, '.:', label="Cycle Consistency + Identity", color='y')
plt.xlabel('Number of voting shapes', fontsize=17)
plt.xticks(x_loc, x_label, fontsize=17)
plt.title("Chair",fontsize=23)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.yticks(fontsize=17)
plt.ylabel('IoU', fontsize=17)
plt.tight_layout()
plt.scatter(0, 93.0,  s=150, color='r', marker='*', label='Oracle + ours')

#legend = plt.legend(loc='lower center', shadow=True, fontsize='x-large')
plt.savefig("Chair.png")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Lamp_NN_ours = [77.14,78.94,79.52,78.26,77.77,77.09,76.50,74.87,59.56,]
Lamp_NN_NN = [76.91,78.78,79.32,77.91,77.33,76.17,75.75,74.24,53.95,]
Lamp_Chamfer_ours = [78.95,78.84,79.67,79.43,78.51,78.14,77.59,76.84,59.56,]
Lamp_Chamfer_NN = [76.66,77.84,78.32,78.38,77.39,77.20,76.70,75.54,53.95,]
Lamp_Cosine_ours = [78.45,80.66,80.14,79.79,78.99,78.16,77.64,76.66,59.55,]
Lamp_Cosine_NN = [77.51,79.63,79.31,78.96,78.50,77.22,76.45,75.35,53.95,]
Lamp_Cycle_ours = [78.55,79.09,79.15,79.05,78.60,79.08,78.23,77.02,59.56,]
Lamp_Cycle_NN = [77.11,77.63,78.09,77.63,77.50,77.51,76.82,75.76,53.95,]

# %%
# %pylab qt
# %matplotlib inline
plt.axhline(y=80.8, xmin=0, xmax=7, linestyle =':', color='k', label = "Pointnet")
plt.plot(x, Lamp_NN_ours, '.-', label="Nearest Neighbors + Ours", color='c')
plt.plot(x, Lamp_NN_NN, '.:', label="Nearest Neighbors + Identity", color='c')
plt.plot(x, Lamp_Chamfer_ours, '.-', label="Chamfer Distance + Ours", color='r')
plt.plot(x, Lamp_Chamfer_NN, '.:', label="Chamfer Distance + Identity", color='r')
plt.plot(x, Lamp_Cosine_ours, '.-', label="Cosine Distance + Ours", color='b')
plt.plot(x, Lamp_Cosine_NN, '.:', label="Cosine Distance + Identity", color='b')
plt.plot(x, Lamp_Cycle_ours, '.-', label="Cycle Consistency + Ours", color='y')
plt.plot(x, Lamp_Cycle_NN, '.:', label="Cycle Consistency + Identity", color='y')
plt.xlabel('Number of voting shapes', fontsize=17)
plt.xticks(x_loc, x_label, fontsize=17)
plt.title("Lamp",  fontsize=23)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.tight_layout()
plt.scatter(0, 93.9,  s=150, color='r', marker='*', label='Oracle + ours')

plt.yticks(fontsize=17)
plt.ylabel('IoU', fontsize=17)
#legend = plt.legend(loc='lower center', shadow=True, fontsize='x-large')
plt.savefig("Lamp.png")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Table_NN_ours = [74.55,75.45,77.30,78.87,78.19,76.66,74.98,74.78,73.02,]
Table_NN_NN = [74.83,75.80,77.46,78.39,77.65,76.24,74.41,73.96,68.66,]
Table_Chamfer_ours = [75.65,76.16,77.55,79.00,79.39,78.80,77.38,76.18,73.02,]
Table_Chamfer_NN = [70.69,72.35,73.93,75.38,75.78,75.59,74.25,73.08,68.66,]
Table_Cosine_ours = [74.43,76.07,77.69,79.42,79.50,77.98,76.41,75.17,73.02,]
Table_Cosine_NN = [74.44,75.92,77.41,78.52,78.95,77.42,75.84,74.31,68.66,]
Table_Cycle_ours = [73.83,75.02,76.95,78.01,78.20,77.74,76.39,75.42,73.02,]
Table_Cycle_NN = [70.81,72.41,73.88,74.44,74.53,74.10,73.02,72.04,68.66,]

# %%
# %pylab qt
# %matplotlib inline
plt.axhline(y=80.6, xmin=0, xmax=7, linestyle =':', color='k', label = "Pointnet")
plt.plot(x, Table_NN_ours, '.-', label="Nearest Neighbors + Ours", color='c')
plt.plot(x, Table_NN_NN, '.:', label="Nearest Neighbors + Identity", color='c')
plt.plot(x, Table_Chamfer_ours, '.-', label="Chamfer Distance + Ours", color='r')
plt.plot(x, Table_Chamfer_NN, '.:', label="Chamfer Distance + Identity", color='r')
plt.plot(x, Table_Cosine_ours, '.-', label="Cosine Distance + Ours", color='b')
plt.plot(x, Table_Cosine_NN, '.:', label="Cosine Distance + Identity", color='b')
plt.plot(x, Table_Cycle_ours, '.-', label="Cycle Consistency + Ours", color='y')
plt.plot(x, Table_Cycle_NN, '.:', label="Cycle Consistency + Identity", color='y')
plt.xlabel('Number of voting shapes', fontsize=17)
plt.xticks(x_loc, x_label, fontsize=17)
plt.title("Table",fontsize=23)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()
plt.scatter(0, 89.3,  s=150, color='r', marker='*', label='Oracle + ours')

plt.gca().spines['top'].set_visible(False)
plt.yticks(fontsize=17)
plt.ylabel('IoU', fontsize=17)
#legend = plt.legend(loc='lower center', shadow=True, fontsize='x-large')
plt.savefig("Table.png")
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
